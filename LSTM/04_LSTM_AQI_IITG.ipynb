# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ashis\anaconda3\envs\tf_env\lib\site-packages (1.7.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.22.0 in c:\users\ashis\anaconda3\envs\tf_env\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ashis\anaconda3\envs\tf_env\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ashis\anaconda3\envs\tf_env\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ashis\anaconda3\envs\tf_env\lib\site-packages (from scikit-learn) (3.6.0)

# %% [markdown]
# # AQI Forecasting — LSTM Model
# **Dataset:** AnandVihar_AQI_data.csv
# **Target:** Daily mean AQI
# **Model:** Stacked LSTM (Long Short-Term Memory) Neural Network
#
# LSTMs are a type of recurrent neural network designed to learn long-range temporal dependencies.
# They maintain a *cell state* that can carry information across many time steps, making them
# well-suited for complex, non-linear time-series.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

print(f'TensorFlow version: {tf.__version__}')
tf.random.set_seed(42)
np.random.seed(42)
# Out:
# TensorFlow version: 2.21.0

# %% [markdown]
# ## 1. Load & Preprocess Data

# %%
df = pd.read_csv('D:/AQI_Project/Data/Final/IITG_AQI_daily_clean.csv', parse_dates=['Timestamp'])
df = df.set_index('Timestamp').sort_index()
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce').interpolate(method='time')

daily = df.resample('D').mean().dropna(subset=['AQI'])
print(f'Daily records: {len(daily)}')
# Out:
# Daily records: 1200

# %% [markdown]
# ## 2. Multivariate Setup & Normalization

# %%
# Use AQI + pollutant sub-indices as features
feature_cols = ['AQI', 'PM25', 'PM10', 'NO2', 'SO2', 'O3']
daily[feature_cols] = daily[feature_cols].ffill().bfill()

# Scale to [0, 1]
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

data_scaled = scaler_X.fit_transform(daily[feature_cols])
aqi_scaled  = scaler_y.fit_transform(daily[['AQI']])

print(f'Feature matrix shape: {data_scaled.shape}')
# Out:
# Feature matrix shape: (1200, 6)

# %% [markdown]
# ## 3. Create Sequence Windows

# %%
SEQ_LEN = 30  # Use 30 days of history to predict next day

def create_sequences(X, y, seq_len):
    Xs, ys = [], []
    for i in range(seq_len, len(X)):
        Xs.append(X[i-seq_len:i])
        ys.append(y[i])
    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(data_scaled, aqi_scaled.flatten(), SEQ_LEN)
print(f'Sequence shape: X={X_seq.shape}, y={y_seq.shape}')
print(f'Input shape per sample: (timesteps={SEQ_LEN}, features={len(feature_cols)})')
# Out:
# Sequence shape: X=(1170, 30, 6), y=(1170,)
# Input shape per sample: (timesteps=30, features=6)

# %% [markdown]
# ## 4. Train/Test Split

# %%
# Align with daily index (offset by SEQ_LEN)
dates = daily.index[SEQ_LEN:]
split_idx = np.searchsorted(dates, pd.Timestamp('2025-07-01'))

X_train, X_test = X_seq[:split_idx], X_seq[split_idx:]
y_train, y_test = y_seq[:split_idx], y_seq[split_idx:]
dates_test = dates[split_idx:]

# Further split train into train+val
val_idx = int(len(X_train) * 0.85)
X_tr, X_val = X_train[:val_idx], X_train[val_idx:]
y_tr, y_val = y_train[:val_idx], y_train[val_idx:]

print(f'Train={len(X_tr)}, Val={len(X_val)}, Test={len(X_test)}')
# Out:
# Train=838, Val=148, Test=184

# %% [markdown]
# ## 5. Build Stacked LSTM Model

# %%
def build_lstm(seq_len, n_features):
    model = Sequential([
        LSTM(128, return_sequences=True, input_shape=(seq_len, n_features)),
        Dropout(0.2),
        BatchNormalization(),
        LSTM(64, return_sequences=True),
        Dropout(0.2),
        BatchNormalization(),
        LSTM(32, return_sequences=False),
        Dropout(0.1),
        Dense(16, activation='relu'),
        Dense(1)
    ])
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='huber'  # Robust to outliers vs MSE
    )
    return model

model = build_lstm(SEQ_LEN, len(feature_cols))
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 128)        │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 30, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 132,257 (516.63 KB)
#  Trainable params: 131,873 (515.13 KB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# ## 6. Train Model

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, verbose=1, min_lr=1e-5)
]

history = model.fit(
    X_tr, y_tr,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - loss: 0.0352 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0167 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0141 - val_loss: 0.0162 - learning_rate: 0.0010
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0137 - val_loss: 0.0181 - learning_rate: 0.0010
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0126 - val_loss: 0.0191 - learning_rate: 0.0010
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0115 - val_loss: 0.0188 - learning_rate: 0.0010
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0111 - val_loss: 0.0153 - learning_rate: 0.0010
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0102 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0106 - val_loss: 0.0147 - learning_rate: 0.0010
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0100 - val_loss: 0.0131 - learning_rate: 0.0010
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.0094 - val_loss: 0.0110 - learning_rate: 0.0010
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0093 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0089 - val_loss: 0.0104 - learning_rate: 0.0010
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0083 - val_loss: 0.0104 - learning_rate: 0.0010
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0083 - val_loss: 0.0097 - learning_rate: 0.0010
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0083 - val_loss: 0.0098 - learning_rate: 0.0010
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0079 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0080 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0078 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0081 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0072 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0078 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0072 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0071 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0065 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0069 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0065 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0065 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0065 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0066 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0059 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0065 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0060 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0055 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0058 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0060 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0052 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0056 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 39/100
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0058
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0056 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0057 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0053 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0054 - val_loss: 0.0047 - learning_rate: 5.0000e-04
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0052 - val_loss: 0.0046 - learning_rate: 5.0000e-04
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0051 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0050 - val_loss: 0.0041 - learning_rate: 5.0000e-04
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0047
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0049 - val_loss: 0.0047 - learning_rate: 5.0000e-04
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0050 - val_loss: 0.0045 - learning_rate: 2.5000e-04
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0046 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0046 - val_loss: 0.0049 - learning_rate: 2.5000e-04
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0047 - val_loss: 0.0049 - learning_rate: 2.5000e-04
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0048 - val_loss: 0.0052 - learning_rate: 2.5000e-04
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0047 - val_loss: 0.0045 - learning_rate: 2.5000e-04
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0047
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0049 - val_loss: 0.0049 - learning_rate: 2.5000e-04
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0047 - val_loss: 0.0050 - learning_rate: 1.2500e-04
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0047 - val_loss: 0.0052 - learning_rate: 1.2500e-04
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0040 - val_loss: 0.0053 - learning_rate: 1.2500e-04
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0044 - val_loss: 0.0052 - learning_rate: 1.2500e-04
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0044 - val_loss: 0.0049 - learning_rate: 1.2500e-04
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0042 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 60/100
# 25/27 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0045
# Epoch 60: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0044 - val_loss: 0.0050 - learning_rate: 1.2500e-04
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 45.

# %%
# Plot training history
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='Train Loss (Huber)', color='steelblue')
ax.plot(history.history['val_loss'], label='Val Loss (Huber)', color='crimson')
ax.set_title('LSTM Training History')
ax.set_xlabel('Epoch')
ax.set_ylabel('Huber Loss')
ax.legend()
plt.tight_layout()
plt.savefig('lstm_training_history_iitg.png', dpi=150)
plt.show()

# %% [markdown]
# ## 7. Forecast & Evaluation

# %%
# Direct (one-step-ahead for each test window using actual data)
pred_scaled = model.predict(X_test, verbose=0)
pred_aqi = scaler_y.inverse_transform(pred_scaled.reshape(-1, 1)).flatten()
actual_aqi = scaler_y.inverse_transform(y_test.reshape(-1, 1)).flatten()

rmse = np.sqrt(mean_squared_error(actual_aqi, pred_aqi))
mae  = mean_absolute_error(actual_aqi, pred_aqi)
mape = np.mean(np.abs((actual_aqi - pred_aqi) / actual_aqi)) * 100

print(f'LSTM Performance on Test Set:')
print(f'  RMSE : {rmse:.2f}')
print(f'  MAE  : {mae:.2f}')
print(f'  MAPE : {mape:.2f}%')
# Out:
# LSTM Performance on Test Set:
#   RMSE : 28.09
#   MAE  : 23.93
#   MAPE : 65.05%

# %%
# Get last 180 days of training for context
train_aqi_orig = scaler_y.inverse_transform(y_train[-180:].reshape(-1, 1)).flatten()
train_dates    = dates[split_idx-180:split_idx]

fig, ax = plt.subplots(figsize=(14, 5))
ax.plot(train_dates, train_aqi_orig, label='Train (last 180d)', color='steelblue')
ax.plot(dates_test, actual_aqi, label='Actual', color='black', linewidth=1.5)
ax.plot(dates_test, pred_aqi, label='LSTM Forecast', color='purple', linestyle='--')
ax.set_title(f'LSTM Forecast  |  RMSE={rmse:.1f}  MAE={mae:.1f}', fontsize=13)
ax.set_ylabel('AQI')
ax.legend()
plt.tight_layout()
plt.savefig('lstm_forecast_iitg.png', dpi=150)
plt.show()

# %% [markdown]
# ## 8. Residual Analysis

# %%
residuals = actual_aqi - pred_aqi
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].plot(dates_test, residuals, color='purple', alpha=0.7)
axes[0].axhline(0, linestyle='--', color='black')
axes[0].set_title('Residuals over time')
axes[1].hist(residuals, bins=40, color='purple', alpha=0.7)
axes[1].set_title('Residual Distribution')
axes[2].scatter(pred_aqi, residuals, alpha=0.4, color='purple', s=10)
axes[2].axhline(0, linestyle='--', color='black')
axes[2].set_title('Residuals vs Predicted')
plt.tight_layout()
plt.savefig('lstm_residuals_iitg.png', dpi=150)
plt.show()

# %%
# Save model weights
model.save('lstm_IITG_aqi_model.keras')
print('Model saved to lstm_IITG_aqi_model.keras')
# Out:
# Model saved to lstm_IITG_aqi_model.keras
