# %%
try:
    import sklearn, tensorflow
except ImportError:
    import subprocess, sys
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'scikit-learn', 'tensorflow'])
    print('Dependencies installed -- restart kernel if imports still fail.')

# %% [markdown]
# # AQI Forecasting — LSTM Model
# **Dataset:** IITG_AQI_data.csv
# **Target:** Daily mean AQI
# **Model:** Stacked LSTM (Long Short-Term Memory) Neural Network
#
# LSTMs are a type of recurrent neural network designed to learn long-range temporal dependencies.
# They maintain a *cell state* that can carry information across many time steps, making them
# well-suited for complex, non-linear time-series.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

print(f'TensorFlow version: {tf.__version__}')
tf.random.set_seed(42)
np.random.seed(42)
# Out:
# TensorFlow version: 2.21.0

# %% [markdown]
# ## 1. Load & Preprocess Data

# %%
df = pd.read_csv('D:/AQI_Project/Data/Final/IITG_AQI_daily_clean.csv', parse_dates=['Timestamp'])
df = df.set_index('Timestamp').sort_index()
df = df.drop(columns=['AQI_Category'], errors='ignore')   # drop string col before resample
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce').interpolate(method='time')

daily = df.resample('D').mean().dropna(subset=['AQI'])
print(f'Daily records: {len(daily)}')
# Out:
# Daily records: 1200

# %% [markdown]
# ## 2. Multivariate Setup & Normalization

# %%
# Features: pollutants only; AQI is target (avoid double-scaling)
feature_cols = ['PM25', 'PM10', 'NO2', 'SO2', 'NH3', 'CO', 'O3']
target_col   = ['AQI']

daily[feature_cols + target_col] = daily[feature_cols + target_col].ffill().bfill()

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(daily[feature_cols])
y_scaled = scaler_y.fit_transform(daily[target_col])

# Stack scaled AQI as last column for LSTM input
data_scaled      = __import__('numpy').hstack([X_scaled, y_scaled])
all_feature_cols = feature_cols + ['AQI']

print(f'Feature matrix shape: {data_scaled.shape}')
print(f'Features: {all_feature_cols}')
# Out:
# Feature matrix shape: (1200, 8)
# Features: ['PM25', 'PM10', 'NO2', 'SO2', 'NH3', 'CO', 'O3', 'AQI']

# %% [markdown]
# ## 3. Create Sequence Windows

# %%
SEQ_LEN = 60  # EDA ACF: strong autocorrelation up to ~60 days (was 30)

def create_sequences(X, y, seq_len):
    Xs, ys = [], []
    for i in range(seq_len, len(X)):
        Xs.append(X[i-seq_len:i])
        ys.append(y[i])
    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(data_scaled, y_scaled.flatten(), SEQ_LEN)
print(f'Sequence shape: X={X_seq.shape}, y={y_seq.shape}')
print(f'Input shape per sample: (timesteps={SEQ_LEN}, features={len(feature_cols)})')
# Out:
# Sequence shape: X=(1140, 60, 8), y=(1140,)
# Input shape per sample: (timesteps=60, features=7)

# %% [markdown]
# ## 4. Train/Test Split

# %%
# Align with daily index (offset by SEQ_LEN)
dates = daily.index[SEQ_LEN:]
split_idx = np.searchsorted(dates, pd.Timestamp('2025-07-01'))

X_train, X_test = X_seq[:split_idx], X_seq[split_idx:]
y_train, y_test = y_seq[:split_idx], y_seq[split_idx:]
dates_test = dates[split_idx:]

# Further split train into train+val
val_idx = int(len(X_train) * 0.85)
X_tr, X_val = X_train[:val_idx], X_train[val_idx:]
y_tr, y_val = y_train[:val_idx], y_train[val_idx:]

print(f'Train={len(X_tr)}, Val={len(X_val)}, Test={len(X_test)}')
# Out:
# Train=812, Val=144, Test=184

# %% [markdown]
# ## 5. Build Stacked LSTM Model

# %%
def build_lstm(seq_len, n_features):
    model = Sequential([
        LSTM(128, return_sequences=True, input_shape=(seq_len, n_features)),
        Dropout(0.2),
        BatchNormalization(),
        LSTM(64, return_sequences=True),
        Dropout(0.2),
        BatchNormalization(),
        LSTM(32, return_sequences=False),
        Dropout(0.1),
        Dense(16, activation='relu'),
        Dense(1)
    ])
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='huber'  # Robust to outliers vs MSE
    )
    return model

model = build_lstm(SEQ_LEN, len(all_feature_cols))   # 8 features: 7 pollutants + AQI
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 128)        │        70,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 60, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 60, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 60, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 133,281 (520.63 KB)
#  Trainable params: 132,897 (519.13 KB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# ## 6. Train Model

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, verbose=1, min_lr=1e-5)
]

history = model.fit(
    X_tr, y_tr,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0434 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0190 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0152 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0145 - val_loss: 0.0132 - learning_rate: 0.0010
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0120 - val_loss: 0.0122 - learning_rate: 0.0010
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0118 - val_loss: 0.0143 - learning_rate: 0.0010
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0120 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0111 - val_loss: 0.0108 - learning_rate: 0.0010
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0102 - val_loss: 0.0103 - learning_rate: 0.0010
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0091 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0088 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0089 - val_loss: 0.0108 - learning_rate: 0.0010
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0089 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0082 - val_loss: 0.0094 - learning_rate: 0.0010
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0078 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0078 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0076 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0076 - val_loss: 0.0102 - learning_rate: 0.0010
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0077 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0074 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0067 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 22/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0069
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0071 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0064 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0066 - val_loss: 0.0076 - learning_rate: 5.0000e-04
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0058 - val_loss: 0.0087 - learning_rate: 5.0000e-04
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0064 - val_loss: 0.0087 - learning_rate: 5.0000e-04
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0062 - val_loss: 0.0088 - learning_rate: 5.0000e-04
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0062 - val_loss: 0.0093 - learning_rate: 5.0000e-04
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0056 - val_loss: 0.0073 - learning_rate: 5.0000e-04
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0056 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0055 - val_loss: 0.0088 - learning_rate: 5.0000e-04
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0063 - val_loss: 0.0094 - learning_rate: 5.0000e-04
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0055 - val_loss: 0.0095 - learning_rate: 5.0000e-04
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0056 - val_loss: 0.0077 - learning_rate: 5.0000e-04
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0055 - val_loss: 0.0077 - learning_rate: 5.0000e-04
# Epoch 36/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0053
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0057 - val_loss: 0.0082 - learning_rate: 5.0000e-04
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0056 - val_loss: 0.0098 - learning_rate: 2.5000e-04
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0057 - val_loss: 0.0116 - learning_rate: 2.5000e-04
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0054 - val_loss: 0.0100 - learning_rate: 2.5000e-04
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0053 - val_loss: 0.0095 - learning_rate: 2.5000e-04
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0053 - val_loss: 0.0090 - learning_rate: 2.5000e-04
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0049 - val_loss: 0.0102 - learning_rate: 2.5000e-04
# Epoch 43/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0053
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0055 - val_loss: 0.0110 - learning_rate: 2.5000e-04
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0056 - val_loss: 0.0093 - learning_rate: 1.2500e-04
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 29.

# %%
# Plot training history
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='Train Loss (Huber)', color='steelblue')
ax.plot(history.history['val_loss'], label='Val Loss (Huber)', color='crimson')
ax.set_title('LSTM Training History')
ax.set_xlabel('Epoch')
ax.set_ylabel('Huber Loss')
ax.legend()
plt.tight_layout()
import os
os.makedirs('images', exist_ok=True)
plt.savefig('images/lstm_training_history_iitg.png', dpi=150)
plt.show()

# %% [markdown]
# ## 7. Forecast & Evaluation

# %%
# Direct (one-step-ahead for each test window using actual data)
pred_scaled = model.predict(X_test, verbose=0)
pred_aqi = scaler_y.inverse_transform(pred_scaled.reshape(-1, 1)).flatten()
actual_aqi = scaler_y.inverse_transform(y_test.reshape(-1, 1)).flatten()

rmse = np.sqrt(mean_squared_error(actual_aqi, pred_aqi))
mae  = mean_absolute_error(actual_aqi, pred_aqi)
mape = np.mean(np.abs((actual_aqi - pred_aqi) / actual_aqi)) * 100

print(f'LSTM Performance on Test Set:')
print(f'  RMSE : {rmse:.2f}')
print(f'  MAE  : {mae:.2f}')
print(f'  MAPE : {mape:.2f}%')
# Out:
# LSTM Performance on Test Set:
#   RMSE : 19.88
#   MAE  : 17.14
#   MAPE : 43.21%

# %%
# Get last 180 days of training for context
train_aqi_orig = scaler_y.inverse_transform(y_train[-180:].reshape(-1, 1)).flatten()
train_dates    = dates[split_idx-180:split_idx]

fig, ax = plt.subplots(figsize=(14, 5))
ax.plot(train_dates, train_aqi_orig, label='Train (last 180d)', color='steelblue')
ax.plot(dates_test, actual_aqi, label='Actual', color='black', linewidth=1.5)
ax.plot(dates_test, pred_aqi, label='LSTM Forecast', color='purple', linestyle='--')
ax.set_title(f'LSTM Forecast  |  RMSE={rmse:.1f}  MAE={mae:.1f}', fontsize=13)
ax.set_ylabel('AQI')
ax.legend()
plt.tight_layout()
import os
os.makedirs('images', exist_ok=True)
plt.savefig('images/lstm_forecast_iitg.png', dpi=150)
plt.show()

# %% [markdown]
# ## 8. Residual Analysis

# %%
residuals = actual_aqi - pred_aqi
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].plot(dates_test, residuals, color='purple', alpha=0.7)
axes[0].axhline(0, linestyle='--', color='black')
axes[0].set_title('Residuals over time')
axes[1].hist(residuals, bins=40, color='purple', alpha=0.7)
axes[1].set_title('Residual Distribution')
axes[2].scatter(pred_aqi, residuals, alpha=0.4, color='purple', s=10)
axes[2].axhline(0, linestyle='--', color='black')
axes[2].set_title('Residuals vs Predicted')
plt.tight_layout()
import os
os.makedirs('images', exist_ok=True)
plt.savefig('images/lstm_residuals_iitg.png', dpi=150)
plt.show()

# %% [markdown]
# ## 8. Classification Metrics & Confusion Matrix
# Converting continuous AQI forecasts into discrete AQI categories to evaluate classification performance (Accuracy, Precision, Recall).

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os

# Define AQI categories based on Indian standards
def categorize_aqi(aqi_values):
    categories = []
    for val in aqi_values:
        if val <= 50:
            categories.append('Good')
        elif val <= 100:
            categories.append('Satisfactory')
        elif val <= 200:
            categories.append('Moderate')
        elif val <= 300:
            categories.append('Poor')
        elif val <= 400:
            categories.append('Very Poor')
        else:
            categories.append('Severe')
    return np.array(categories)

# Ensure values are flattened arrays
y_true_cont = np.array(actual_aqi).flatten()
y_pred_cont = np.array(pred_aqi).flatten()

# Convert continuous predictions to discrete AQI classes
y_true_class = categorize_aqi(y_true_cont)
y_pred_class = categorize_aqi(y_pred_cont)

# Labels for standard Indian AQI
labels = ['Good', 'Satisfactory', 'Moderate', 'Poor', 'Very Poor', 'Severe']
# Filter labels to only those present in the actual or predicted to avoid empty rows/cols if desired
# But keeping all labels shows a full matrix
present_labels = [l for l in labels if l in y_true_class or l in y_pred_class]

# Calculate Metrics
acc = accuracy_score(y_true_class, y_pred_class)
# weighted average for precision and recall since it's multiclass
prec = precision_score(y_true_class, y_pred_class, average='weighted', zero_division=0)
rec = recall_score(y_true_class, y_pred_class, average='weighted', zero_division=0)

print(f"Classification Metrics for AQI Categories:")
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f} (Weighted)")
print(f"Recall:    {rec:.4f} (Weighted)\n")

print("Classification Report:")
print(classification_report(y_true_class, y_pred_class, labels=present_labels, zero_division=0))

# Confusion Matrix
cm = confusion_matrix(y_true_class, y_pred_class, labels=present_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=present_labels, yticklabels=present_labels)
plt.title('AQI Classification Confusion Matrix')
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')

os.makedirs('images', exist_ok=True)
plt.savefig('images/lstm_confusion_matrix_iitg.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Classification Metrics for AQI Categories:
# Accuracy:  0.5054
# Precision: 0.8041 (Weighted)
# Recall:    0.5054 (Weighted)
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       1.00      0.08      0.15        87
# Satisfactory       0.38      0.98      0.55        56
#     Moderate       0.97      0.76      0.85        41
#
#     accuracy                           0.51       184
#    macro avg       0.78      0.61      0.52       184
# weighted avg       0.80      0.51      0.43       184

# %%
# Save model weights
model.save('saved_models/lstm_IITG_aqi_model.keras')
print('Model saved as lstm_IITG_aqi_model.keras')
# Out:
# Model saved as lstm_IITG_aqi_model.keras
