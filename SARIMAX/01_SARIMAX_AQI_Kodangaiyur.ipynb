# %% [markdown]
# # AQI Forecasting — SARIMAX Model
# **Station:** Kodungaiyur, Chennai
# **Dataset:** Kodungaiyur_AQI_daily_clean.csv
# **Target:** Daily mean AQI
# **Model:** SARIMAX(2,1,2)(1,1,1,7) + Fourier exogenous terms
#
# **Improvements over plain ARIMA baseline:**
# - Weekly seasonal order `(1,1,1,7)` captures weekday/weekend emission cycles
# - Fourier terms (K=3) model the annual cycle (winter haze, pre-monsoon / post-monsoon transitions)
# - Rolling one-step-ahead forecast avoids compounding error over the test horizon
# - Exogenous pollutant/weather columns auto-detected and included if present

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import warnings
import os
warnings.filterwarnings('ignore')

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    confusion_matrix, classification_report,
    accuracy_score, precision_score, recall_score,
)
from tqdm import tqdm   # pip install tqdm

# ── Paths & constants ─────────────────────────────────────────
STATION_NAME = 'Kodungaiyur'
INPUT_FILE   = f'D:/AQI_Project/data/Final/{STATION_NAME}_AQI_daily_clean.csv'
IMAGE_DIR    = 'images'
MODEL_DIR    = r'D:/AQI_Project/SARIMAX/saved_models'

os.makedirs(IMAGE_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)

print('✅ Libraries loaded successfully.')
# Out:
# ✅ Libraries loaded successfully.

# %% [markdown]
# ## 1. Load & Preprocess Data

# %%
STATION_NAME = 'Kodungaiyur'
# Load full dataset — keep all columns so exog features can be extracted later
df = pd.read_csv(INPUT_FILE, parse_dates=['Date'])
df = df.set_index('Date').sort_index()

# Interpolate any missing AQI values
df['AQI'] = df['AQI'].interpolate(method='time')

# Resample hourly → daily mean
daily = df['AQI'].resample('D').mean().dropna()

print(f'Total daily records : {len(daily)}')
print(f'Date range          : {daily.index[0].date()} → {daily.index[-1].date()}')
print(f'All columns         : {df.columns.tolist()}')
print()
print('AQI Statistics:')
print(daily.describe().round(2))
# Out:
# Total daily records : 1826
# Date range          : 2021-01-01 → 2025-12-31
# All columns         : ['NO', 'NOx', 'Benzene', 'Toluene', 'RH', 'WS', 'WD', 'RF', 'TOT-RF', 'SR', 'PM25', 'PM10', 'NO2', 'SO2', 'NH3', 'CO', 'O3', 'AQI', 'AQI_Category']
#
# AQI Statistics:
# count    1826.00
# mean       75.41
# std        51.35
# min        16.54
# 25%        47.43
# 50%        64.54
# 75%        87.53
# max       443.88
# Name: AQI, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(14, 4))
ax.plot(daily.index, daily.values, color='steelblue', lw=0.8)
ax.set_title(f'{STATION_NAME} — Daily Mean AQI (2021–2025)', fontsize=14)
ax.set_ylabel('AQI')
ax.set_xlabel('Date')
ax.xaxis.set_major_locator(mdates.AutoDateLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig(f'{IMAGE_DIR}/sarimax_full_series_{STATION_NAME}.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 2. Stationarity Check (ADF Test)

# %%
result = adfuller(daily.dropna())
print('ADF Test — original series:')
print(f'  ADF Statistic : {result[0]:.4f}')
print(f'  p-value       : {result[1]:.4f}')
print(f'  Critical 1%   : {result[4]["1%"]:.4f}')
print(f'  Critical 5%   : {result[4]["5%"]:.4f}')
print()
if result[1] < 0.05:
    print('✅ Series is STATIONARY (d=0 may suffice).')
else:
    print('⚠️  Series is NON-STATIONARY → differencing needed (d=1).')

result_d1 = adfuller(daily.diff().dropna())
print(f'\nADF on first difference: p-value = {result_d1[1]:.4f}')
if result_d1[1] < 0.05:
    print('✅ First difference is stationary → d=1 confirmed.')
# Out:
# ADF Test — original series:
#   ADF Statistic : -6.0793
#   p-value       : 0.0000
#   Critical 1%   : -3.4340
#   Critical 5%   : -2.8631
#
# ✅ Series is STATIONARY (d=0 may suffice).
#
# ADF on first difference: p-value = 0.0000
# ✅ First difference is stationary → d=1 confirmed.

# %% [markdown]
# ## 3. ACF & PACF Analysis

# %%
# Kodungaiyur series is non-stationary → plot ACF/PACF on first-differenced series
fig, axes = plt.subplots(1, 2, figsize=(14, 4))
plot_acf( daily.diff().dropna(), lags=40, ax=axes[0], title='ACF — First Difference')
plot_pacf(daily.diff().dropna(), lags=40, ax=axes[1], title='PACF — First Difference')
plt.tight_layout()
plt.savefig(f'{IMAGE_DIR}/sarimax_acf_pacf_{STATION_NAME}.png', dpi=150, bbox_inches='tight')
plt.show()
print('ACF/PACF interpretation: p=2, d=1, q=2  →  SARIMAX order=(2,1,2)')
print('Weekly seasonal lags visible at lag-7 multiples  →  seasonal_order=(1,1,1,7)')
# Out:
# ACF/PACF interpretation: p=2, d=1, q=2  →  SARIMAX order=(2,1,2)
# Weekly seasonal lags visible at lag-7 multiples  →  seasonal_order=(1,1,1,7)

# %% [markdown]
# ## 4. Train / Test Split

# %%
# Last ~10% of data as held-out test set (chronological — no shuffle)
split_date = '2025-07-01'
train = daily[:split_date]
test  = daily[split_date:]

print(f'Train : {len(train):,} days  ({train.index[0].date()} → {train.index[-1].date()})')
print(f'Test  : {len(test):,} days  ({test.index[0].date()}  → {test.index[-1].date()})')
# Out:
# Train : 1,643 days  (2021-01-01 → 2025-07-01)
# Test  : 184 days  (2025-07-01  → 2025-12-31)

# %% [markdown]
# ## 5. Exogenous Feature Engineering
#
# Two types of exogenous inputs are constructed:
#
# | Feature group | Details | Rationale |
# |---|---|---|
# | **Fourier terms** | sin/cos pairs, K=3, period=365.25 d | Approximates annual cycle (winter haze, pre/post-monsoon transitions) without slow `seasonal_order=(1,1,1,365)` |
# | **Pollutant / weather cols** | PM25, PM10, NO2, SO2, CO, WS, RH, AT, BP — auto-detected | Direct physical drivers of AQI that pure time-series structure cannot capture |

# %%
def make_fourier(index, period=365.25, K=3):
    """K sine/cosine pairs approximating a seasonal cycle of `period` days."""
    t = np.arange(len(index))
    cols = {}
    for k in range(1, K + 1):
        cols[f'sin_{k}'] = np.sin(2 * np.pi * k * t / period)
        cols[f'cos_{k}'] = np.cos(2 * np.pi * k * t / period)
    return pd.DataFrame(cols, index=index)

# Auto-detect usable exogenous columns present in the dataset
EXOG_CANDIDATES = ['PM25', 'PM10', 'NO2', 'SO2', 'CO', 'WS', 'RH', 'AT', 'BP']
exog_cols = [c for c in EXOG_CANDIDATES if c in df.columns]
print(f'Exogenous columns found : {exog_cols if exog_cols else "None — Fourier only"}')

# Fourier terms over the full daily index
fourier_all = make_fourier(daily.index, period=365.25, K=3)

# Merge pollutant/weather cols (resampled to daily mean) + Fourier
if exog_cols:
    exog_phys = df[exog_cols].resample('D').mean().reindex(daily.index).interpolate('time')
    exog_all  = pd.concat([exog_phys, fourier_all], axis=1)
else:
    exog_all = fourier_all

exog_all = exog_all.ffill().bfill()

print(f'Exog feature matrix : {exog_all.shape}')
print(f'Features            : {exog_all.columns.tolist()}')
# Out:
# Exogenous columns found : ['PM25', 'PM10', 'NO2', 'SO2', 'CO', 'WS', 'RH']
# Exog feature matrix : (1826, 13)
# Features            : ['PM25', 'PM10', 'NO2', 'SO2', 'CO', 'WS', 'RH', 'sin_1', 'cos_1', 'sin_2', 'cos_2', 'sin_3', 'cos_3']

# %%
# Split exog to match endog train/test indices exactly
exog_train = exog_all.loc[train.index]
exog_test  = exog_all.loc[test.index]

print(f'exog_train : {exog_train.shape}')
print(f'exog_test  : {exog_test.shape}')
# Out:
# exog_train : (1643, 13)
# exog_test  : (184, 13)

# %% [markdown]
# ## 6. Fit SARIMAX
#
# **Model:** `SARIMAX(2,1,2)(1,1,1,7)`
# - `order=(2,1,2)` — same AR/I/MA as ARIMA baseline; `d=1` because Kodungaiyur series is non-stationary
# - `seasonal_order=(1,1,1,7)` — weekly seasonal cycle with seasonal differencing
# - Fourier + physical exog — encode annual cycle and external pollution drivers linearly

# %%
print('Fitting SARIMAX(2,1,2)(1,1,1,7) + Fourier exog ...')

sarimax_model = SARIMAX(
    train,
    exog=exog_train,
    order=(2, 1, 2),
    seasonal_order=(1, 1, 1, 7),
    enforce_stationarity=False,
    enforce_invertibility=False,
    trend='c',
)
sarimax_fit = sarimax_model.fit(disp=False, maxiter=200)
print(sarimax_fit.summary())
# Out:
# Fitting SARIMAX(2,1,2)(1,1,1,7) + Fourier exog ...
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                 AQI   No. Observations:                 1643
# Model:             SARIMAX(2, 1, 2)x(1, 1, [1], 7)   Log Likelihood               -5734.755
# Date:                             Tue, 19 May 2026   AIC                          11511.510
# Time:                                     23:38:37   BIC                          11624.769
# Sample:                                 01-01-2021   HQIC                         11553.534
#                                       - 07-01-2025
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -3.646e-06   4.35e-05     -0.084      0.933    -8.9e-05    8.17e-05
# PM25           0.4185      0.007     57.117      0.000       0.404       0.433
# PM10           0.6579      0.010     62.958      0.000       0.637       0.678
# NO2           -0.0036      0.145     -0.025      0.980      -0.287       0.280
# SO2            0.4707      0.033     14.460      0.000       0.407       0.534
# CO             0.2467      0.041      6.055      0.000       0.167       0.326
# WS            -0.2929      0.997     -0.294      0.769      -2.248       1.662
# RH            -0.2562      0.223     -1.149      0.251      -0.693       0.181
# sin_1          6.7892     16.824      0.404      0.687     -26.186      39.764
# cos_1         26.2617     18.048      1.455      0.146      -9.113      61.636
# sin_2         -1.8209      9.364     -0.194      0.846     -20.173      16.532
# cos_2          7.6819      8.822      0.871      0.384      -9.609      24.973
# sin_3          3.6500      6.756      0.540      0.589      -9.592      16.892
# cos_3          2.3846      6.569      0.363      0.717     -10.491      15.260
# ar.L1          1.1500      0.115      9.969      0.000       0.924       1.376
# ar.L2         -0.1744      0.107     -1.634      0.102      -0.384       0.035
# ma.L1         -1.3638      0.110    -12.385      0.000      -1.580      -1.148
# ma.L2          0.3644      0.111      3.293      0.001       0.148       0.581
# ar.S.L7        0.0032      0.032      0.100      0.920      -0.059       0.065
# ma.S.L7       -0.9660      0.017    -56.463      0.000      -1.000      -0.932
# sigma2        94.8241      3.339     28.398      0.000      88.279     101.369
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):             94989.12
# Prob(Q):                              0.76   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.51   Skew:                            -1.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                        40.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## 7. Forecast & Evaluation
#
# Two forecasting strategies are compared:
#
# | Strategy | Description | Use case |
# |---|---|---|
# | **Open-loop** | All steps forecast in one shot from the training end | Shows degradation — mirrors the ARIMA baseline approach |
# | **Rolling (1-step-ahead)** | Re-conditions on each new actual observation before forecasting the next | Realistic operational evaluation; avoids compounding error |

# %%
# ── Rolling one-step-ahead forecast ─────────────────────────
# Uses model.filter(params) — fast Kalman filter pass — instead of
# re-fitting from scratch at each step (~10x speedup).

print(f'Running rolling forecast over {len(test)} steps ...')
print('(Uses filter, not refit — estimated time: 2–5 min depending on hardware)\n')

history_endog = train.copy()
history_exog  = exog_train.copy()
rolling_preds = []
params        = sarimax_fit.params   # warm-start params from initial fit

for i in tqdm(range(len(test))):
    m = SARIMAX(
        history_endog,
        exog=history_exog,
        order=(2, 1, 2),
        seasonal_order=(1, 1, 1, 7),
        enforce_stationarity=False,
        enforce_invertibility=False,
        trend='c',
    )
    f  = m.filter(params)
    fc = f.forecast(steps=1, exog=exog_test.iloc[[i]])
    rolling_preds.append(float(fc.iloc[0]))

    # Append actual value so next step conditions on truth, not prediction
    history_endog = pd.concat([history_endog, test.iloc[[i]]])
    history_exog  = pd.concat([history_exog,  exog_test.iloc[[i]]])

forecast_rolling = pd.Series(rolling_preds, index=test.index)
print('\n✅ Rolling forecast complete.')
# Out:
# Running rolling forecast over 184 steps ...
# (Uses filter, not refit — estimated time: 2–5 min depending on hardware)
#   1%|          | 1/184 [00:00<01:11,  2.56it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   1%|          | 2/184 [00:00<01:10,  2.60it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   2%|▏         | 3/184 [00:01<01:13,  2.45it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   2%|▏         | 4/184 [00:01<01:15,  2.39it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   3%|▎         | 5/184 [00:02<01:11,  2.51it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   3%|▎         | 6/184 [00:02<01:08,  2.59it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   4%|▍         | 7/184 [00:02<01:06,  2.67it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   4%|▍         | 8/184 [00:03<01:06,  2.64it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   5%|▍         | 9/184 [00:03<01:09,  2.53it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   5%|▌         | 10/184 [00:03<01:12,  2.41it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   6%|▌         | 11/184 [00:04<01:14,  2.32it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   7%|▋         | 12/184 [00:04<01:14,  2.30it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   7%|▋         | 13/184 [00:05<01:13,  2.32it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   8%|▊         | 14/184 [00:05<01:13,  2.33it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   8%|▊         | 15/184 [00:06<01:12,  2.32it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   9%|▊         | 16/184 [00:06<01:15,  2.23it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#   9%|▉         | 17/184 [00:07<01:11,  2.34it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  10%|▉         | 18/184 [00:07<01:07,  2.46it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  10%|█         | 19/184 [00:07<01:05,  2.52it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  11%|█         | 20/184 [00:08<01:04,  2.53it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  11%|█▏        | 21/184 [00:08<01:03,  2.58it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  12%|█▏        | 22/184 [00:08<01:02,  2.60it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  12%|█▎        | 23/184 [00:09<01:02,  2.56it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  13%|█▎        | 24/184 [00:09<01:02,  2.54it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  14%|█▎        | 25/184 [00:10<01:03,  2.51it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  14%|█▍        | 26/184 [00:10<01:01,  2.58it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  15%|█▍        | 27/184 [00:10<00:59,  2.64it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  15%|█▌        | 28/184 [00:11<00:58,  2.66it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  16%|█▌        | 29/184 [00:11<00:58,  2.65it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  16%|█▋        | 30/184 [00:12<00:58,  2.62it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  17%|█▋        | 31/184 [00:12<00:58,  2.62it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  17%|█▋        | 32/184 [00:12<00:56,  2.70it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  18%|█▊        | 33/184 [00:13<00:56,  2.68it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  18%|█▊        | 34/184 [00:13<00:54,  2.75it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  19%|█▉        | 35/184 [00:13<00:56,  2.62it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  20%|█▉        | 36/184 [00:14<00:57,  2.59it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  20%|██        | 37/184 [00:14<00:54,  2.68it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  21%|██        | 38/184 [00:14<00:54,  2.68it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  21%|██        | 39/184 [00:15<00:52,  2.78it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  22%|██▏       | 40/184 [00:15<00:50,  2.86it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  22%|██▏       | 41/184 [00:16<00:51,  2.80it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  23%|██▎       | 42/184 [00:16<00:51,  2.74it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  23%|██▎       | 43/184 [00:16<00:51,  2.76it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  24%|██▍       | 44/184 [00:17<00:52,  2.68it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  24%|██▍       | 45/184 [00:17<00:51,  2.71it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  25%|██▌       | 46/184 [00:17<00:49,  2.77it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  26%|██▌       | 47/184 [00:18<00:49,  2.78it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  26%|██▌       | 48/184 [00:18<00:47,  2.85it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  27%|██▋       | 49/184 [00:18<00:46,  2.90it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  27%|██▋       | 50/184 [00:19<00:44,  2.99it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  28%|██▊       | 51/184 [00:19<00:43,  3.04it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  28%|██▊       | 52/184 [00:19<00:42,  3.12it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  29%|██▉       | 53/184 [00:20<00:42,  3.11it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  29%|██▉       | 54/184 [00:20<00:41,  3.11it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  30%|██▉       | 55/184 [00:20<00:40,  3.18it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  30%|███       | 56/184 [00:21<00:40,  3.18it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  31%|███       | 57/184 [00:21<00:39,  3.21it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  32%|███▏      | 58/184 [00:21<00:39,  3.16it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  32%|███▏      | 59/184 [00:22<00:41,  3.04it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  33%|███▎      | 60/184 [00:22<00:40,  3.03it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  33%|███▎      | 61/184 [00:22<00:42,  2.90it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...
#   return get_prediction_index(
#  89%|████████▉ | 164/184 [00:55<00:06,  3.17it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  90%|████████▉ | 165/184 [00:56<00:06,  3.12it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  90%|█████████ | 166/184 [00:56<00:05,  3.13it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  91%|█████████ | 167/184 [00:56<00:05,  3.05it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  91%|█████████▏| 168/184 [00:57<00:05,  3.05it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  92%|█████████▏| 169/184 [00:57<00:04,  3.11it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  92%|█████████▏| 170/184 [00:57<00:04,  3.08it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  93%|█████████▎| 171/184 [00:58<00:04,  3.09it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  93%|█████████▎| 172/184 [00:58<00:03,  3.11it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  94%|█████████▍| 173/184 [00:58<00:03,  2.98it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  95%|█████████▍| 174/184 [00:59<00:03,  3.08it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  95%|█████████▌| 175/184 [00:59<00:02,  3.15it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  96%|█████████▌| 176/184 [00:59<00:02,  3.20it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  96%|█████████▌| 177/184 [01:00<00:02,  3.19it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  97%|█████████▋| 178/184 [01:00<00:01,  3.22it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  97%|█████████▋| 179/184 [01:00<00:01,  3.20it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  98%|█████████▊| 180/184 [01:01<00:01,  3.21it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  98%|█████████▊| 181/184 [01:01<00:00,  3.21it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  99%|█████████▉| 182/184 [01:01<00:00,  3.20it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#  99%|█████████▉| 183/184 [01:02<00:00,  3.21it/s]c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ashis\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 100%|██████████| 184/184 [01:02<00:00,  2.95it/s]
# ✅ Rolling forecast complete.

# %%
# ── Open-loop forecast (all steps at once, for comparison) ──
forecast_open = sarimax_fit.forecast(steps=len(test), exog=exog_test)
forecast_open.index = test.index

# ── Metrics helper ────────────────────────────────────────────
def regression_metrics(actual, predicted, label):
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    mae  = mean_absolute_error(actual, predicted)
    mask = actual.values != 0
    mape = np.mean(np.abs((actual.values[mask] - np.array(predicted)[mask])
                          / actual.values[mask])) * 100
    print(f'{label:<42s}  RMSE={rmse:6.2f}  MAE={mae:6.2f}  MAPE={mape:5.2f}%')
    return rmse, mae, mape

print('=' * 72)
rmse_open, mae_open, mape_open = regression_metrics(
    test, forecast_open,    'SARIMAX open-loop')
rmse_roll, mae_roll, mape_roll = regression_metrics(
    test, forecast_rolling, 'SARIMAX rolling    (1-step-ahead)')
print('=' * 72)
print()
print('Note: XGBoost (separate notebook) achieves RMSE ≈ 6–8 on hourly data.')
# Out:
# ========================================================================
# SARIMAX open-loop                           RMSE= 25.18  MAE= 17.79  MAPE=21.45%
# SARIMAX rolling    (1-step-ahead)           RMSE= 19.66  MAE=  9.35  MAPE= 8.61%
# ========================================================================
#
# Note: XGBoost (separate notebook) achieves RMSE ≈ 6–8 on hourly data.

# %%
# ── Forecast plot ─────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(16, 5))

# Last 180 days of train for context
train_tail = train.iloc[-180:]
ax.plot(train_tail.index, train_tail.values,
        color='steelblue', lw=0.9, label='Train (last 180 d)')

# Actual test
ax.plot(test.index, test.values,
        color='black', lw=1.5, label='Actual')

# Open-loop (degrading)
ax.plot(forecast_open.index, forecast_open.values,
        color='tomato', linestyle='--', lw=1.2,
        label=f'SARIMAX open-loop  (RMSE={rmse_open:.1f})')

# Rolling (realistic)
ax.plot(forecast_rolling.index, forecast_rolling.values,
        color='crimson', linestyle='-', lw=1.3,
        label=f'SARIMAX rolling     (RMSE={rmse_roll:.1f})')

# 95% CI from open-loop fit
pred_obj = sarimax_fit.get_forecast(steps=len(test), exog=exog_test)
ci = pred_obj.conf_int()
ci.index = test.index
ax.fill_between(ci.index, ci.iloc[:, 0], ci.iloc[:, 1],
                alpha=0.15, color='crimson', label='95% CI (open-loop)')

# Indian AQI category threshold lines
for level, col in zip([50, 100, 200, 300, 400],
                      ['#2ecc71', '#a8e063', '#f1c40f', '#e67e22', '#e74c3c']):
    ax.axhline(level, color=col, linestyle='--', lw=0.7, alpha=0.5)

ax.set_xlim(train_tail.index[0], test.index[-1])
ax.xaxis.set_major_locator(mdates.AutoDateLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=30)
ax.set_title(
    f'SARIMAX(2,1,2)(1,1,1,7) + Fourier — {STATION_NAME}  |  '
    f'Rolling RMSE={rmse_roll:.1f}  MAE={mae_roll:.1f}',
    fontsize=13
)
ax.set_ylabel('AQI')
ax.legend(fontsize=9)
plt.tight_layout()
plt.savefig(f'{IMAGE_DIR}/sarimax_forecast_{STATION_NAME}.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 8. Residual Diagnostics

# %%
# Residuals from rolling forecast (the realistic evaluation)
residuals = test.values - forecast_rolling.values

fig, axes = plt.subplots(1, 3, figsize=(16, 4))

# Time plot
axes[0].plot(test.index, residuals, color='gray', lw=0.7, alpha=0.8)
axes[0].axhline(0, color='red', lw=1)
axes[0].set_title('Residuals over Time')
axes[0].set_ylabel('Actual − Predicted')
axes[0].xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=20)

# Distribution
axes[1].hist(residuals, bins=40, color='steelblue', edgecolor='white', density=True)
axes[1].set_title(
    f'Residual Distribution\n(μ={residuals.mean():.1f}, σ={residuals.std():.1f})')
axes[1].set_xlabel('Residual')

# ACF
plot_acf(residuals, lags=30, ax=axes[2], title='ACF of Residuals')

plt.suptitle(f'SARIMAX Residual Analysis — {STATION_NAME} (Rolling Forecast)',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{IMAGE_DIR}/sarimax_residuals_{STATION_NAME}.png', dpi=150, bbox_inches='tight')
plt.show()

# Ljung-Box test for residual autocorrelation
from statsmodels.stats.diagnostic import acorr_ljungbox
lb = acorr_ljungbox(residuals, lags=[7, 14, 21], return_df=True)
print('Ljung-Box test (H0: no residual autocorrelation):')
print(lb.to_string())
print()
if (lb['lb_pvalue'] > 0.05).all():
    print('✅ Residuals show no significant autocorrelation — model is well-specified.')
else:
    print('⚠️  Residual autocorrelation detected — consider increasing p or q.')
# Out:
# Ljung-Box test (H0: no residual autocorrelation):
#       lb_stat  lb_pvalue
# 7   13.736802   0.056066
# 14  15.625535   0.336773
# 21  20.045869   0.518357
#
# ✅ Residuals show no significant autocorrelation — model is well-specified.

# %% [markdown]
# ## 9. Classification Metrics & Confusion Matrix
#
# Converting continuous AQI forecasts to discrete Indian AQI categories
# to evaluate Accuracy, Precision, and Recall alongside regression metrics.
# Both open-loop and rolling forecasts are evaluated.

# %%
def categorize_aqi(aqi_values):
    """Map continuous AQI to Indian standard 6-tier categories."""
    cats = []
    for v in aqi_values:
        if   v <= 50:  cats.append('Good')
        elif v <= 100: cats.append('Satisfactory')
        elif v <= 200: cats.append('Moderate')
        elif v <= 300: cats.append('Poor')
        elif v <= 400: cats.append('Very Poor')
        else:          cats.append('Severe')
    return np.array(cats)

y_true_cont  = test.values.flatten()
y_true_class = categorize_aqi(y_true_cont)

LABELS = ['Good', 'Satisfactory', 'Moderate', 'Poor', 'Very Poor', 'Severe']

for name, preds in [('Open-loop', forecast_open.values),
                    ('Rolling',   forecast_rolling.values)]:
    y_pred_class = categorize_aqi(preds.flatten())
    present      = [l for l in LABELS if l in y_true_class or l in y_pred_class]
    acc  = accuracy_score(y_true_class, y_pred_class)
    prec = precision_score(y_true_class, y_pred_class, average='weighted', zero_division=0)
    rec  = recall_score(y_true_class, y_pred_class, average='weighted', zero_division=0)
    print(f'── SARIMAX {name} ─────────────────────────────────')
    print(f'  Accuracy  : {acc:.4f}')
    print(f'  Precision : {prec:.4f} (weighted)')
    print(f'  Recall    : {rec:.4f} (weighted)')
    print()
    print(classification_report(y_true_class, y_pred_class,
                                labels=present, zero_division=0))
    print()
# Out:
# ── SARIMAX Open-loop ─────────────────────────────────
#   Accuracy  : 0.6957
#   Precision : 0.7718 (weighted)
#   Recall    : 0.6957 (weighted)
#
#               precision    recall  f1-score   support
#
#         Good       0.44      0.90      0.59        30
# Satisfactory       0.90      0.60      0.72       104
#     Moderate       0.82      0.82      0.82        39
#         Poor       0.50      1.00      0.67         7
#    Very Poor       0.00      0.00      0.00         3
#       Severe       0.00      0.00      0.00         1
#
#     accuracy                           0.70       184
#    macro avg       0.44      0.55      0.47       184
# weighted avg       0.77      0.70      0.70       184
#
#
# ── SARIMAX Rolling ─────────────────────────────────
#   Accuracy  : 0.8859
#   Precision : 0.8860 (weighted)
#   Recall    : 0.8859 (weighted)
#
#               precision    recall  f1-score   support
#
#         Good       0.90      0.87      0.88        30
# Satisfactory       0.95      0.93      0.94       104
#     Moderate       0.87      0.87      0.87        39
#         Poor       0.46      0.86      0.60         7
#    Very Poor       0.00      0.00      0.00         3
#       Severe       0.00      0.00      0.00         1
#
#     accuracy                           0.89       184
#    macro avg       0.53      0.59      0.55       184
# weighted avg       0.89      0.89      0.88       184

# %%
# ── Confusion matrices side by side ─────────────────────────
LABELS = ['Good', 'Satisfactory', 'Moderate', 'Poor', 'Very Poor', 'Severe']
y_true_class = categorize_aqi(test.values.flatten())

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
for ax, (name, preds) in zip(axes, [('Open-loop', forecast_open.values),
                                      ('Rolling',   forecast_rolling.values)]):
    y_pred_class = categorize_aqi(preds.flatten())
    present      = [l for l in LABELS if l in y_true_class or l in y_pred_class]
    cm = confusion_matrix(y_true_class, y_pred_class, labels=present)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=present, yticklabels=present, ax=ax)
    acc = accuracy_score(y_true_class, y_pred_class)
    ax.set_title(f'SARIMAX {name} — Accuracy={acc:.3f}', fontsize=12, fontweight='bold')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.suptitle(f'AQI Classification Confusion Matrix — {STATION_NAME}',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{IMAGE_DIR}/sarimax_confusion_matrix_{STATION_NAME}.png',
            dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 10. Model Comparison Summary

# %%
# ── Paste your ARIMA baseline numbers here ───────────────────
# (from the original 01_ARIMA_AQI_Kodangaiyur notebook run)
arima_rmse, arima_mae, arima_mape = None, None, None   # ← fill in

rows = []
if arima_rmse is not None:
    rows.append({
        'Model'   : 'ARIMA(2,1,2) — open-loop baseline',
        'RMSE'    : arima_rmse,
        'MAE'     : arima_mae,
        'MAPE%'   : arima_mape,
        'Strategy': 'open-loop',
    })
rows += [
    {'Model'   : 'SARIMAX(2,1,2)(1,1,1,7) — open-loop',
     'RMSE'    : round(rmse_open, 2), 'MAE': round(mae_open, 2),
     'MAPE%'   : round(mape_open, 2), 'Strategy': 'open-loop'},
    {'Model'   : 'SARIMAX(2,1,2)(1,1,1,7) — rolling 1-step',
     'RMSE'    : round(rmse_roll, 2), 'MAE': round(mae_roll, 2),
     'MAPE%'   : round(mape_roll, 2), 'Strategy': 'rolling'},
    {'Model'   : 'XGBoost (hourly, separate notebook)',
     'RMSE'    : '~6–8', 'MAE': '~4–6', 'MAPE%': '~5–8',
     'Strategy': 'direct + recursive'},
]

summary = pd.DataFrame(rows).set_index('Model')
print()
print('=' * 75)
print(f'  MODEL COMPARISON — {STATION_NAME} AQI')
print('=' * 75)
print(summary.to_string())
print('=' * 75)
# Out:
# ===========================================================================
#   MODEL COMPARISON — Kodungaiyur AQI
# ===========================================================================
#                                            RMSE    MAE  MAPE%            Strategy
# Model
# SARIMAX(2,1,2)(1,1,1,7) — open-loop       25.18  17.79  21.45           open-loop
# SARIMAX(2,1,2)(1,1,1,7) — rolling 1-step  19.66   9.35   8.61             rolling
# XGBoost (hourly, separate notebook)        ~6–8   ~4–6   ~5–8  direct + recursive
# ===========================================================================

# %% [markdown]
# ## 11. Save Model

# %%
import pickle

model_path = f'{MODEL_DIR}/sarimax_{STATION_NAME.lower()}.pkl'
with open(model_path, 'wb') as f:
    pickle.dump(sarimax_fit, f)

print(f'✅ SARIMAX model saved → {model_path}')
print(f'   Order          : (2,1,2)(1,1,1,7)')
print(f'   Exog features  : {exog_all.columns.tolist()}')
print(f'   Train samples  : {len(train)}')
print(f'   Rolling RMSE   : {rmse_roll:.2f}')
print(f'   Rolling MAE    : {mae_roll:.2f}')
# Out:
# ✅ SARIMAX model saved → D:/AQI_Project/SARIMAX/saved_models/sarimax_kodungaiyur.pkl
#    Order          : (2,1,2)(1,1,1,7)
#    Exog features  : ['PM25', 'PM10', 'NO2', 'SO2', 'CO', 'WS', 'RH', 'sin_1', 'cos_1', 'sin_2', 'cos_2', 'sin_3', 'cos_3']
#    Train samples  : 1643
#    Rolling RMSE   : 19.66
#    Rolling MAE    : 9.35
